# %%
import dash
import pandas as pd
from dash import html

# %%
df = pd.read_csv("../data/raw/stores_sales.csv")

# %%
app = dash.Dash(__name__)

app.layout = html.H1("Dash is working!"),

app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 app = dash.Dash(__name__)
#       3 app.layout = html.H1("Dash is working!"),
# ----> 4 fig_sales_trend = px.line(df, x="order_date", y="sales", title="Sales Over Time")
#       8 app.run(debug=True)
#
# NameError: name 'px' is not defined
