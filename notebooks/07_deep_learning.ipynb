# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import tensorflow

from pathlib import Path
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

RANDOM_STATE = 42

# %% [markdown]
# ### Loading Assets

# %%
path =
